# %%
import requests

API_KEY = "AIzaSyCfgZM7gXT8fiA0YN2dbFZBJcsAuCiFI_o"
API_URL = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key={API_KEY}"
PROMPT_FILE = "Prompt.txt"  
RAW_TEXT_FILE = "raw_data/document_to_anonymize.txt"
OUTPUT_FILE = "output.txt"
TEMPERATURE = 0.0

def generate_content(prompt_text: str, temperature: float) -> dict:
    """Envia o prompt para a API Gemini e retorna a resposta."""
    headers = {
        "Content-Type": "application/json"
    }
    body = {
        "contents": [
            {
                "parts": [
                    {"text": prompt_text}
                ]
            }
        ],
        "generationConfig": {
            "temperature": temperature
        }
    }
    response = requests.post(API_URL, headers=headers, json=body)
    return response.json()

try:
    with open(PROMPT_FILE, "r", encoding="utf-8") as f:
        prompt_with_examples = f.read()
except FileNotFoundError:
    print(f"Erro: {PROMPT_FILE} não encontrado.")
    exit()

try:
    with open(RAW_TEXT_FILE, "r", encoding="utf-8") as f:
        raw_text = f.read()
except FileNotFoundError:
    print(f"Erro: {RAW_TEXT_FILE} não encontrado.")
    exit()

final_prompt = f"{prompt_with_examples}\n\nRaw Text to Anonymize:\n{raw_text}"

output = generate_content(final_prompt, TEMPERATURE)

try:
    response_text = output['candidates'][0]['content']['parts'][0]['text']
    
    
    with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
        f.write(response_text)
    print(response_text)

except (KeyError, IndexError):
    print("Erro: Formato de resposta inesperado da API.")
    print(output)
# Out:
# Relatorio de Admissao Centro Medico Lisboa
#
# Data *
# Referencia *
#
# Informacoes do Paciente
#
# Nome *
# Data de Nascimento *
# Sexo Feminino
# NIF *
# Cartao de Cidadao *
# Morada Centro
# Telefone *
# Email *
# Numero da Seguranca Social *
#
# Historico Medico
#
# A paciente * mulher caucasiana de 45-59 anos compareceu a consulta relatando dores
# abdominais intensas Tem historico de hipertensao e diabetes tipo 2 diagnosticada ha 5 anos E
# HIV positivo desde 2018 atualmente com carga viral indetectavel gracas ao tratamento com
# antirretrovirais
#
# A paciente relatou que sua familia tem historico de cancro da mama mae falecida aos 52 anos
# e doenca cardiaca pai e avo paterno Exames geneticos realizados em 2022 indicaram
# predisposicao ao cancro de mama mutacao BRCA1 positiva
#
# Informacoes Sociais e Comportamentais
#
# Estado civil *
# Filhos Sim
# Religiao *
# Ocupacao Área de educação
# Habitos Exfumante parou ha 3 anos consome alcool socialmente 23 doses por semana
# ...

# %%
from fpdf import FPDF
import os
pdf = FPDF()   

pdf.add_page()
  
pdf.set_font("Arial", size = 12)

try:
    with open("output.txt", "r") as f:
        line_height = 10
        page_height = 277 
        current_y = 10

        lines = [line.strip() for line in f if line.strip()]

        for line in lines:
            if current_y + line_height > page_height:
                pdf.add_page()
                current_y = 10
            pdf.cell(0, line_height, txt =line, ln = 1, align = 'L')
            current_y += line_height
    output= "output.pdf" 
    pdf.output(output) 
    print("OKAK")  
    os.startfile(output) 
  
except FileNotFoundError:
    print("Error: 'test.txt' not found. Please check the file path.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# OKAK
